# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(-1, 1, 200, endpoint=False)
sig  = np.cos(2 * np.pi * 7 * t) + signal.gausspulse(t - 0.4, fc=2)
widths = np.arange(1, 31)
cwtmatr = signal.cwt(sig, signal.ricker, widths)

# %%
print(cwtmatr)
# Out:
# [[0.12295729 0.82403097 0.49659403 ... 0.03778416 0.41158457 0.88748015]
#  [0.69769974 1.43730443 1.60158153 ... 0.61310832 1.30673555 1.37748468]
#  [1.34653365 1.81454133 1.83427207 ... 0.48377523 1.18359425 1.40976794]
#  ...
#  [0.09547932 0.08849822 0.08116842 ... 0.30182776 0.35401421 0.40324284]
#  [0.0902296  0.08113826 0.07175717 ... 0.23613821 0.28545125 0.33304506]
#  [0.08276783 0.07114499 0.05934224 ... 0.18429729 0.23045273 0.27607165]]

# %%
plt.plot(sig)

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt

# Generate a test signal
t = np.linspace(0, 1, num=1000)
signal = np.sin(2 * np.pi * 10 * t) + np.sin(2 * np.pi * 20 * t)

# Define the wavelet family and level of decomposition
wavelet = 'db4'  # Daubechies 4 wavelet
level = 5       # Level of decomposition

# Perform wavelet decomposition
coeffs = pywt.wavedec(signal, wavelet, level=level)

# Reconstruct the signal using wavelet coefficients
reconstructed_signal = pywt.waverec(coeffs, wavelet)

# Plot the original and reconstructed signals
plt.figure(figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.plot(t, signal)
plt.title('Original Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')

plt.subplot(2, 1, 2)
plt.plot(t, reconstructed_signal)
plt.title('Reconstructed Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()

# %%
#code with analysis

import pywt
import numpy as np
import matplotlib.pyplot as plt

f = 2
t = np.linspace(0,1,100)
signal = np.sin(2*np.pi*f*t)
plt.plot(signal)
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.title("signal")
# Out:
# Text(0.5, 1.0, 'signal')

# %%
noise = np.random.normal(0,0.125,100)
signal_noise =  signal + noise
plt.plot(signal)
plt.plot(signal_noise)
plt.title("signal with noise")
plt.xlabel("time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
wavelet = 'db7'
level = 3
coeff = pywt.wavedec(signal_noise, wavelet, level=level)
#print(coeff)
approx = coeff[0]
detail = coeff[1:]
plt.plot(approx)
plt.show()
for i in range(level,0,-1):
    #print(f'level{i}:{coeffs[i]}')
    plt.subplot(level+2,i,i+2)
    plt.plot(coeffs[i])
    plt.ylabel('Level{}'.format(i+1))
    coeff[i] = np.zeros(len(coeff[i]))
    recons = pywt.waverec(coeff,wavelet)
    plt.figure(figsize=(10,4))
    plt.plot(t,signal)
    plt.plot(t,recons)
    plt.xlabel('time')
    plt.ylabel('amplitude')
    plt.title('reconstructed signal')
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
recons = pywt.waverec(coeff, wavelet)
plt.plot(signal)
plt.plot(recons)

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
freq=1
amp=1
duration=1
samplingrate=1000
t =np.linspace(0,duration,int(samplingrate*duration),endpoint=False)
cleansig = amp*np.sin(2*np.pi*freq*t)
mean = 0
stddev = 0.1
noise = np.random.normal(mean, stddev, cleansig.shape)
noisysig= cleansig+noise
plt.figure(figsize=(10,4))
plt.plot(t,cleansig,label='cleansig',color='green')
plt.plot(t,noisysig,label='noisysig',color='red')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.title('noisy signal')
plt.legend()
plt.show()
signal = noisysig
wavelet = 'db7'
level = 6
coeffs = pywt.wavedec(signal,wavelet,level=level)
print(len(coeffs))
for i in range(level,0,-1):
    print(f'level{i}:{coeffs[i]}')
    plt.subplot(level+2,i,i+2)
    plt.plot(coeffs[i])
    plt.ylabel('Level{}'.format(i+1))
    coeffs[i] = np.zeros(len(coeffs[i]))
    recons = pywt.waverec(coeffs,wavelet)
    plt.figure(figsize=(10,4))
    plt.plot(t,cleansig,label='cleansig',color='green')
    plt.plot(t,recons,label='reconstructed',color='red')
    plt.xlabel('time')
    plt.ylabel('amplitude')
    plt.title('reconstructed signal')
    plt.legend()
    plt.show()
# Out:
# 7
# level6:[ 1.69327039e-02 -8.97949852e-02 -4.91376178e-02 -8.72626854e-02
#  -1.47522475e-01  7.14689393e-02 -9.94900508e-02 -2.10639560e-03
#  -1.93501725e-01 -1.24466538e-01  1.52549162e-02  2.30431708e-02
#   5.88279312e-02  2.70469728e-02 -8.23963365e-02  6.96738384e-02
#  -4.75632471e-02 -1.52429659e-01 -7.37585873e-02 -1.34374932e-01
#   5.56961062e-02 -8.10317190e-02 -8.83657788e-02  2.45848611e-02
#   4.17732436e-02  9.86037066e-02  7.29162466e-03 -1.88160549e-01
#  -2.15462651e-03 -7.09170822e-02 -1.07135573e-01  9.93326466e-04
#  -9.90578386e-03  2.67256274e-01  6.21384267e-02 -3.91621739e-02
#  -8.55441683e-02  5.70847621e-02 -2.72067563e-02 -4.23059131e-02
#  -2.90353319e-01 -1.47538647e-01 -1.00077137e-01  2.06468721e-02
#   3.56808032e-02 -8.79007916e-02  4.77635382e-02  5.54358351e-02
#  -1.02626185e-01  2.12305357e-02 -3.70680456e-03  2.05207611e-01
#  -1.67843759e-02  1.30009474e-02 -1.30850190e-01 -4.13604679e-02
# ...
